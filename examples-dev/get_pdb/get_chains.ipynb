# %%
# pip install pooled-ppi @ git+https://github.com/jurgjn/pooled-ppi@develop
from pprint import pprint
import pooled_ppi.yeast_pools as yp
# Out:
# yeast_pools.py:22 Using data from: /cluster/project/beltrao/jjaenes/25.12_pooled-ppi-yeast/data
# /cluster/project/beltrao/jjaenes/25.12_pooled-ppi-yeast/data/resources/.cached_path

# %%
# Get models with the protein-of-interest (p0c2j7) from the table of all models
af3_id = 'p0c2j7'
pairs = yp.get_models(filters=[[('af3_id1', '==', af3_id)], [('af3_id2', '==', af3_id)]]).sample(5)
pairs
# Out:
#      af3_id1 af3_id2 chain_id1 chain_id2  \
# 2466  p0c2j7  q12403         A         G
# 1345  p0c2j7  q03768         A         G
# 232   p0c2j7  q03508         A         G
# 1154  p0c2j7  q12129         A         J
# 2019  p0c2j7  q3e805         A         E
#
#                                     input_name input_type  sample  \
# 2466  80a3982b490e5703e71e1e9983baf03c9f9cc801       pool       1
# 1345  f09704312500a344c2d4645457605164914ab3c8       pool       0
# 232   00019830653823e4cd6c1dcc6fb8e19c2ea15f53       pool       3
# 1154  8b226f8ffa9e83a49d2adb1e6e2a5791909b1cdd       pool       3
# 2019  d5bdd5a3bb4edfa363f53db7b62284a5b9b2cb6a       pool       4
#
#       chain_pair_iptm  chain_pair_pae_min  \
# 2466             0.17               29.55
# 1345             0.17               29.45
# 232              0.18               30.28
# 1154             0.17               30.69
# 2019             0.16               30.72
#
#                                             db_id1  \
# 2466  80a3982b490e5703e71e1e9983baf03c9f9cc801_1_A
# 1345  f09704312500a344c2d4645457605164914ab3c8_0_A
# 232   00019830653823e4cd6c1dcc6fb8e19c2ea15f53_3_A
# 1154  8b226f8ffa9e83a49d2adb1e6e2a5791909b1cdd_3_A
# 2019  d5bdd5a3bb4edfa363f53db7b62284a5b9b2cb6a_4_A
#
#                                             db_id2
# 2466  80a3982b490e5703e71e1e9983baf03c9f9cc801_1_G
# 1345  f09704312500a344c2d4645457605164914ab3c8_0_G
# 232   00019830653823e4cd6c1dcc6fb8e19c2ea15f53_3_G
# 1154  8b226f8ffa9e83a49d2adb1e6e2a5791909b1cdd_3_J
# 2019  d5bdd5a3bb4edfa363f53db7b62284a5b9b2cb6a_4_E

# %%
# Get unique structure identifiers corresponding to af3_id
db_ids = set(pairs.query('af3_id1 == @af3_id')['db_id1'].tolist() + pairs.query('af3_id2 == @af3_id')['db_id2'].tolist())
pprint(sorted(db_ids))
# Out:
# ['00019830653823e4cd6c1dcc6fb8e19c2ea15f53_3_A',
#  '80a3982b490e5703e71e1e9983baf03c9f9cc801_1_A',
#  '8b226f8ffa9e83a49d2adb1e6e2a5791909b1cdd_3_A',
#  'd5bdd5a3bb4edfa363f53db7b62284a5b9b2cb6a_4_A',
#  'f09704312500a344c2d4645457605164914ab3c8_0_A']

# %%
# use db_ids to load/save the files
for db_id in db_ids:
    path = f'{db_id}.pdb'
    yp.save_predictions_db([db_id], path)
    print(path, 'written')
# Out:
# 8b226f8ffa9e83a49d2adb1e6e2a5791909b1cdd_3_A.pdb written
# f09704312500a344c2d4645457605164914ab3c8_0_A.pdb written
# 80a3982b490e5703e71e1e9983baf03c9f9cc801_1_A.pdb written
# d5bdd5a3bb4edfa363f53db7b62284a5b9b2cb6a_4_A.pdb written
# 00019830653823e4cd6c1dcc6fb8e19c2ea15f53_3_A.pdb written

# %%
# Current directory has PDBs
# !ls -l *.pdb
# Out:
# -rw-r--r-- 1 jjaenes biol-imsb-beltrao 1183742 Jul 10 16:01 00019830653823e4cd6c1dcc6fb8e19c2ea15f53_3_A.pdb
# -rw-r--r-- 1 jjaenes biol-imsb-beltrao 1183742 Jul 10 16:01 80a3982b490e5703e71e1e9983baf03c9f9cc801_1_A.pdb
# -rw-r--r-- 1 jjaenes biol-imsb-beltrao 1183742 Jul 10 16:00 8b226f8ffa9e83a49d2adb1e6e2a5791909b1cdd_3_A.pdb
# -rw-r--r-- 1 jjaenes biol-imsb-beltrao 1183742 Jul 10 16:01 d5bdd5a3bb4edfa363f53db7b62284a5b9b2cb6a_4_A.pdb
# -rw-r--r-- 1 jjaenes biol-imsb-beltrao 1183742 Jul 10 16:01 f09704312500a344c2d4645457605164914ab3c8_0_A.pdb
