# %%
# pip install pooled-ppi @ git+https://github.com/jurgjn/pooled-ppi@develop
from pprint import pprint
import pooled_ppi.yeast_pools as yp
# Out:
# yeast_pools.py:22 Using data from: /cluster/work/beltrao/jjaenes/25.12_pooled-ppi-yeast/data-26.07
# /cluster/work/beltrao/jjaenes/25.12_pooled-ppi-yeast/data-26.07/resources/.cached_path

# %%
# Get 5 random models with the protein-of-interest (p0c2j7) from the table of all models
af3_id = 'p0c2j7'
pairs = yp.get_models(filters=[[('af3_id1', '==', af3_id)], [('af3_id2', '==', af3_id)]]).sample(5)
pairs
# Out:
#      af3_id1 af3_id2 chain_id1 chain_id2  \
# 560   p0c2j7  q03705         B         I
# 1590  p0c2j7  p53389         A         H
# 1456  p0c2j7  p15646         B         C
# 1412  p0c2j7  p38265         A         D
# 1529  p0c2j7  p47150         B         F
#
#                                     input_name input_type  sample  \
# 560   20285bb50dd6938d5675d7aaff58c5ea5e0297ee       pool       2
# 1590  7576e2f7236c0b4c389361f7c3b91b4228b4df27       pool       1
# 1456  2440dadbf4ca3bed36e190ca8b7022a2aac6f6bb       pool       2
# 1412  16364ca9dbc1442cc9199f32cf11076b242ab885       pool       0
# 1529  492e1c256b463c761de16e599421ce75b57d7a0d       pool       4
#
#       ranking_score  chain_pair_iptm  chain_pair_pae_min  \
# 560        0.349251             0.16               31.46
# 1590       0.324237             0.18               31.27
# 1456       0.322883             0.18               30.70
# 1412       0.339392             0.16               31.31
# 1529       0.347081             0.17               28.87
#
#                                             db_id1  \
# 560   20285bb50dd6938d5675d7aaff58c5ea5e0297ee_2_B
# 1590  7576e2f7236c0b4c389361f7c3b91b4228b4df27_1_A
# 1456  2440dadbf4ca3bed36e190ca8b7022a2aac6f6bb_2_B
# 1412  16364ca9dbc1442cc9199f32cf11076b242ab885_0_A
# 1529  492e1c256b463c761de16e599421ce75b57d7a0d_4_B
#
#                                             db_id2
# 560   20285bb50dd6938d5675d7aaff58c5ea5e0297ee_2_I
# 1590  7576e2f7236c0b4c389361f7c3b91b4228b4df27_1_H
# 1456  2440dadbf4ca3bed36e190ca8b7022a2aac6f6bb_2_C
# 1412  16364ca9dbc1442cc9199f32cf11076b242ab885_0_D
# 1529  492e1c256b463c761de16e599421ce75b57d7a0d_4_F

# %%
# Get unique structure identifiers corresponding to af3_id
db_ids = set(pairs.query('af3_id1 == @af3_id')['db_id1'].tolist() + pairs.query('af3_id2 == @af3_id')['db_id2'].tolist())
pprint(sorted(db_ids))
# Out:
# ['16364ca9dbc1442cc9199f32cf11076b242ab885_0_A',
#  '20285bb50dd6938d5675d7aaff58c5ea5e0297ee_2_B',
#  '2440dadbf4ca3bed36e190ca8b7022a2aac6f6bb_2_B',
#  '492e1c256b463c761de16e599421ce75b57d7a0d_4_B',
#  '7576e2f7236c0b4c389361f7c3b91b4228b4df27_1_A']

# %%
# use db_ids to load/save the files
for db_id in db_ids:
    path = f'{db_id}.pdb'
    yp.save_predictions_db([db_id], path)
    print(path, 'written')
# Out:
# 16364ca9dbc1442cc9199f32cf11076b242ab885_0_A.pdb written
# 492e1c256b463c761de16e599421ce75b57d7a0d_4_B.pdb written
# 2440dadbf4ca3bed36e190ca8b7022a2aac6f6bb_2_B.pdb written
# 7576e2f7236c0b4c389361f7c3b91b4228b4df27_1_A.pdb written
# 20285bb50dd6938d5675d7aaff58c5ea5e0297ee_2_B.pdb written

# %%
# Current directory has PDBs
# !ls -l *.pdb
# Out:
# -rw-r--r-- 1 jjaenes biol-imsb-beltrao 1183742 Jul 14 16:05 16364ca9dbc1442cc9199f32cf11076b242ab885_0_A.pdb
# -rw-r--r-- 1 jjaenes biol-imsb-beltrao 1183742 Jul 14 16:06 20285bb50dd6938d5675d7aaff58c5ea5e0297ee_2_B.pdb
# -rw-r--r-- 1 jjaenes biol-imsb-beltrao 1183742 Jul 14 16:05 2440dadbf4ca3bed36e190ca8b7022a2aac6f6bb_2_B.pdb
# -rw-r--r-- 1 jjaenes biol-imsb-beltrao 1183742 Jul 14 16:05 492e1c256b463c761de16e599421ce75b57d7a0d_4_B.pdb
# -rw-r--r-- 1 jjaenes biol-imsb-beltrao 1183742 Jul 14 16:05 7576e2f7236c0b4c389361f7c3b91b4228b4df27_1_A.pdb
