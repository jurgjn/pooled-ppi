# %%
from pprint import pprint
import pooled_ppi

# %%
# Find pool (`name` column) with the pair-of-interest
pp = pooled_ppi.PooledPredictionsDb('/cluster/project/beltrao/jjaenes/26.01_batch-infer/pooled-ppi-yeast/data')
pp.pairs.query('pair_id1 == "p0c2j7" & pair_id2 == "p47022"')

# %%
# Write PDB with selected chains
pp.save_ids([
    '00019830653823e4cd6c1dcc6fb8e19c2ea15f53_p0c2j7',
    '00019830653823e4cd6c1dcc6fb8e19c2ea15f53_p47022',
], f'p0c2j7_p47022.pdb')
