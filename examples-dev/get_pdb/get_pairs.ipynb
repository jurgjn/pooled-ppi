# %%
# pip install pooled-ppi @ git+https://github.com/jurgjn/pooled-ppi@develop
import pooled_ppi.yeast_pools as yp
# Out:
# yeast_pools.py:24 Using data from: /cluster/work/beltrao/jjaenes/25.12_pooled-ppi-yeast/data-26.07
# /cluster/work/beltrao/jjaenes/25.12_pooled-ppi-yeast/data-26.07/resources/.cached_path

# %%
# o13297 homodimer is in paired input, and one pooled input (each input has 5 models)
# filters argument (to select pairs) is passed on to pd.read_parquet
# foldcomp database identifiers are now {input_name}_{sample}_{chain_id}
# - input_name is either chain uniprot identifiers (for pairs) or hash of the chain identifiers (for pools)
# - sample is from AlphaFold3 (diffusion model sample)
# - chain_id is the original chain identifier in the AlphaFold3 mmcif; foldcomp does not support multimer entries so we're storing individual chains
af3_id = 'o13297'
yp.get_models(filters=[('af3_id1', '==', af3_id), ('af3_id2', '==', af3_id)])
# Out:
#   af3_id1 af3_id2 chain_id1 chain_id2  \
# 0  o13297  o13297         A         B
# 1  o13297  o13297         A         B
# 2  o13297  o13297         A         B
# 3  o13297  o13297         A         B
# 4  o13297  o13297         A         B
# 5  o13297  o13297         A         B
# 6  o13297  o13297         A         B
# 7  o13297  o13297         A         B
# 8  o13297  o13297         A         B
# 9  o13297  o13297         A         B
#
#                                  input_name input_type  \
# 0                             o13297_o13297       pair
# 1                             o13297_o13297       pair
# 2                             o13297_o13297       pair
# 3                             o13297_o13297       pair
# 4                             o13297_o13297       pair
# 5  fc40a600fabb4ea278771889c9e11ea3e2cda50a       pool
# 6  fc40a600fabb4ea278771889c9e11ea3e2cda50a       pool
# 7  fc40a600fabb4ea278771889c9e11ea3e2cda50a       pool
# 8  fc40a600fabb4ea278771889c9e11ea3e2cda50a       pool
# 9  fc40a600fabb4ea278771889c9e11ea3e2cda50a       pool
#
#                                            batch_id  seed  sample  \
# 0  26.06/euler-homodimer_pairs-rtx_pro_6000-b78e215     4       0
# 1  26.06/euler-homodimer_pairs-rtx_pro_6000-b78e215     4       1
# 2  26.06/euler-homodimer_pairs-rtx_pro_6000-b78e215     4       2
# 3  26.06/euler-homodimer_pairs-rtx_pro_6000-b78e215     4       3
# 4  26.06/euler-homodimer_pairs-rtx_pro_6000-b78e215     4       4
# 5    26.06/euler-homodimers-rtx_pro_6000-r3-b78e215     4       0
# 6    26.06/euler-homodimers-rtx_pro_6000-r3-b78e215     4       1
# 7    26.06/euler-homodimers-rtx_pro_6000-r3-b78e215     4       2
# 8    26.06/euler-homodimers-rtx_pro_6000-r3-b78e215     4       3
# 9    26.06/euler-homodimers-rtx_pro_6000-r3-b78e215     4       4
#
#    ranking_score  chain_pair_iptm  chain_pair_pae_min_min  \
# 0       0.782783             0.55                    1.49
# 1       0.773146             0.54                    1.55
# 2       0.741119             0.55                    1.54
# 3       0.783007             0.55                    1.32
# 4       0.752487             0.55                    1.52
# 5       0.338259             0.41                    5.62
# 6       0.356276             0.40                    5.79
# 7       0.358208             0.40                    6.27
# 8       0.344496             0.39                    6.33
# 9       0.343412             0.39                    6.52
#
#    chain_pair_pae_min_max  chain_pair_pae_min_mean  \
# 0                    1.50                    1.495
# 1                    1.56                    1.555
# 2                    1.56                    1.550
# 3                    1.32                    1.320
# 4                    1.54                    1.530
# 5                    5.88                    5.750
# 6                    6.22                    6.005
# 7                    6.48                    6.375
# 8                    6.45                    6.390
# 9                    7.15                    6.835
#
#                                          db_id1  \
# 0                             o13297_o13297_0_A
# 1                             o13297_o13297_1_A
# 2                             o13297_o13297_2_A
# 3                             o13297_o13297_3_A
# 4                             o13297_o13297_4_A
# 5  fc40a600fabb4ea278771889c9e11ea3e2cda50a_0_A
# 6  fc40a600fabb4ea278771889c9e11ea3e2cda50a_1_A
# 7  fc40a600fabb4ea278771889c9e11ea3e2cda50a_2_A
# 8  fc40a600fabb4ea278771889c9e11ea3e2cda50a_3_A
# 9  fc40a600fabb4ea278771889c9e11ea3e2cda50a_4_A
#
#                                          db_id2
# 0                             o13297_o13297_0_B
# 1                             o13297_o13297_1_B
# 2                             o13297_o13297_2_B
# 3                             o13297_o13297_3_B
# 4                             o13297_o13297_4_B
# 5  fc40a600fabb4ea278771889c9e11ea3e2cda50a_0_B
# 6  fc40a600fabb4ea278771889c9e11ea3e2cda50a_1_B
# 7  fc40a600fabb4ea278771889c9e11ea3e2cda50a_2_B
# 8  fc40a600fabb4ea278771889c9e11ea3e2cda50a_3_B
# 9  fc40a600fabb4ea278771889c9e11ea3e2cda50a_4_B

# %%
# extract first model (sample==0) from pair and pool
models = yp.get_models(filters=[('af3_id1', '==', af3_id), ('af3_id2', '==', af3_id), ('sample', '==', 0)])
models
# Out:
#   af3_id1 af3_id2 chain_id1 chain_id2  \
# 0  o13297  o13297         A         B
# 1  o13297  o13297         A         B
#
#                                  input_name input_type  \
# 0                             o13297_o13297       pair
# 1  fc40a600fabb4ea278771889c9e11ea3e2cda50a       pool
#
#                                            batch_id  seed  sample  \
# 0  26.06/euler-homodimer_pairs-rtx_pro_6000-b78e215     4       0
# 1    26.06/euler-homodimers-rtx_pro_6000-r3-b78e215     4       0
#
#    ranking_score  chain_pair_iptm  chain_pair_pae_min_min  \
# 0       0.782783             0.55                    1.49
# 1       0.338259             0.41                    5.62
#
#    chain_pair_pae_min_max  chain_pair_pae_min_mean  \
# 0                    1.50                    1.495
# 1                    5.88                    5.750
#
#                                          db_id1  \
# 0                             o13297_o13297_0_A
# 1  fc40a600fabb4ea278771889c9e11ea3e2cda50a_0_A
#
#                                          db_id2
# 0                             o13297_o13297_0_B
# 1  fc40a600fabb4ea278771889c9e11ea3e2cda50a_0_B

# %%
# use db_id1, db_id2 to save the individual heterodimers as PDB files
for i, row in models.iterrows():
    path = f'{row.af3_id1}_{row.af3_id2}_{row.input_type}_{row["sample"]}.pdb'
    yp.save_predictions_db([row.db_id1, row.db_id2], path)
    print(path, 'written')
# Out:
# 0 o13297_o13297_0_A A
# 1 o13297_o13297_0_B B
# o13297_o13297_pair_0.pdb written
# 0 fc40a600fabb4ea278771889c9e11ea3e2cda50a_0_A A
# 1 fc40a600fabb4ea278771889c9e11ea3e2cda50a_0_B B
# o13297_o13297_pool_0.pdb written

# %%
# Current directory has PDBs
# !ls -l *.pdb
# Out:
# -rw-r--r-- 1 jjaenes biol-imsb-beltrao 705033 Jul 22 10:38 o13297_o13297_pair_0.pdb
# -rw-r--r-- 1 jjaenes biol-imsb-beltrao 705033 Jul 22 10:38 o13297_o13297_pool_0.pdb
