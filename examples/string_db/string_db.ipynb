# %%
import pooled_ppi as pp

# %%
pp.string_db.read_table(data_id='protein.links').head(3)
# Out:
#      protein1      protein2  combined_score
# 0  4932.Q0010  4932.YMR207C             333
# 1  4932.Q0010  4932.YCR051W             205
# 2  4932.Q0010  4932.YPR002W             195

# %%
pp.string_db.read_table(data_id='protein.links.detailed').head(3)
# Out:
#      protein1      protein2  neighborhood  fusion  cooccurence  coexpression  \
# 0  4932.Q0010  4932.YMR207C            45       0            0            95
# 1  4932.Q0010  4932.YCR051W             0       0            0             0
# 2  4932.Q0010  4932.YPR002W             0       0            0            52
#
#    experimental  database  textmining  combined_score
# 0             0       245          99             333
# 1           180         0          71             205
# 2           116         0         117             195

# %%
pp.string_db.read_table(data_id='protein.info').head(3)
# Out:
#   string_protein_id preferred_name  protein_size  \
# 0        4932.Q0010          Q0010           128
# 1        4932.Q0017          Q0017            53
# 2        4932.Q0032          Q0032            96
#
#                                           annotation
# 0  Putative uncharacterized protein Q0010, mitoch...
# 1  Putative uncharacterized protein Q0017, mitoch...
# 2  Putative uncharacterized protein Q0032, mitoch...
