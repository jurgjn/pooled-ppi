# %%
# !head -n 10 sequences.tsv | pooled-ppi-sample --max_pool_size=5000
# Out:
# --init_pools None
# --max_pool_size 5000
# --max_pools None
# {'aac71217.2': 0, 'aac71218.2': 1, 'aac71219.1': 2, 'aac71220.1': 3, 'aac71221.1': 4}
# 4 threads available for numba
# 5 proteins in input
# 100%|███████████████████████████████████████████| 10/10 [00:39<00:00,  3.92s/it]
# 1 pools generated
# 10 interactions expected
# 10 interactions across all pools generated
# True pools include all possible interactions
# 1.0 length-weighted redundancy factor across all pools
# pool_id	pool_size
# aac71217.2_aac71218.2_aac71219.1_aac71220.1_aac71221.1	2593
