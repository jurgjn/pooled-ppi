# %%
pooled-ppi-sample < yeast30.tsv --max_pool_size=3000 --init_pools=yeast30_init.tsv
# Out:
# --init_pools yeast30_init.tsv
# --max_pool_size 3000
# --max_pools None
# {'a0a023pyf4': 0, 'a0a023pzb3': 1, 'a0a023pze8': 2, 'a0a023pzf2': 3, 'a0a023pzg4': 4, 'a0a0b7p221': 5, 'a0a0b7p3v8': 6, 'a0a7m4b2u1': 7, 'a2p2r3': 8, 'a5z2x5': 9, 'd6vpm8': 10, 'd6vtk4': 11, 'd6w196': 12, 'i2hb52': 13, 'i2hb70': 14, 'o13297': 15, 'o13329': 16, 'o13511': 17, 'o13512': 18, 'o13516': 19, 'o13525': 20, 'o13527': 21, 'o13529': 22, 'o13535': 23, 'o13536': 24, 'o13539': 25, 'o13544': 26, 'o13547': 27, 'o13549': 28, 'o13555': 29}
# 4 threads available for numba
# 30 proteins in input
# 100%|█████████████████████████████████████████| 435/435 [01:01<00:00,  7.13it/s]
# 1 pools generated
# 435 interactions expected
# 10 interactions across all pools generated
# False pools include all possible interactions
# 0.026101043468668702 length-weighted redundancy factor across all pools
# pool_id	pool_size
# a0a023pze8_a2p2r3_d6w196_o13329_o13547	1693
