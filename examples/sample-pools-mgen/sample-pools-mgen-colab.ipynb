# %%
# !pip install git+https://github.com/jurgjn/pooled-ppi.git
# Out:
# ...
#   Cloning https://github.com/jurgjn/pooled-ppi.git to /tmp/pip-req-build-xt0qlz4h
#   Running command git clone --filter=blob:none --quiet https://github.com/jurgjn/pooled-ppi.git /tmp/pip-req-build-xt0qlz4h
#   Resolved https://github.com/jurgjn/pooled-ppi.git to commit 4720cf2f62c17a7914ac5be2c004a56ce4a15a82
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 49.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 107.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.7 MB/s eta 0:00:00
# ...
#   Created wheel for pooled-ppi: filename=pooled_ppi-0.1.dev0-py3-none-any.whl size=5696 sha256=15a835d3f9903ba05aab8cec3281695e22379830e2e87c24f970b9c3f71ca5e1
# ...

# %%
# %%bash
# cat << EOF > yeast30.tsv
# af3_id	seq_len
# a0a023pyf4	145
# a0a023pzb3	126
# a0a023pze8	133
# a0a023pzf2	135
# a0a023pzg4	107
# a0a0b7p221	28
# a0a0b7p3v8	1104
# a0a7m4b2u1	118
# a2p2r3	262
# a5z2x5	72
# d6vpm8	179
# d6vtk4	431
# d6w196	494
# i2hb52	66
# i2hb70	103
# o13297	549
# o13329	566
# o13511	128
# o13512	126
# o13516	197
# o13525	335
# o13527	1196
# o13529	151
# o13535	1793
# o13536	103
# o13539	261
# o13544	120
# o13547	238
# o13549	108
# o13555	125
# EOF

# %%
# !pooled-ppi-sample < yeast30.tsv --max_pool_size=3000
# Out:
# --init_pools None
# --max_pool_size 3000
# --max_pools None
# {'a0a023pyf4': 0, 'a0a023pzb3': 1, 'a0a023pze8': 2, 'a0a023pzf2': 3, 'a0a023pzg4': 4, 'a0a0b7p221': 5, 'a0a0b7p3v8': 6, 'a0a7m4b2u1': 7, 'a2p2r3': 8, 'a5z2x5': 9, 'd6vpm8': 10, 'd6vtk4': 11, 'd6w196': 12, 'i2hb52': 13, 'i2hb70': 14, 'o13297': 15, 'o13329': 16, 'o13511': 17, 'o13512': 18, 'o13516': 19, 'o13525': 20, 'o13527': 21, 'o13529': 22, 'o13535': 23, 'o13536': 24, 'o13539': 25, 'o13544': 26, 'o13547': 27, 'o13549': 28, 'o13555': 29}
# 2 threads available for numba
# 30 proteins in input
# 100% 435/435 [00:17<00:00, 24.50it/s]
# 19 pools generated
# 435 interactions expected
# 435 interactions across all pools generated
# True pools include all possible interactions
# 1.3515127755569232 length-weighted redundancy factor across all pools
# pool_id	pool_size
# a0a023pyf4_a0a023pzb3_a0a023pze8_a0a023pzf2_a0a023pzg4_a0a0b7p221_a0a0b7p3v8_o13527	2974
# ...
