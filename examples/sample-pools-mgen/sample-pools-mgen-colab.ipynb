# %%
# !pip install --quiet git+https://github.com/jurgjn/pooled-ppi.git
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 6.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 80.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 112.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 18.0 MB/s eta 0:00:00
#   Building wheel for pooled-ppi (pyproject.toml) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.3.3 which is incompatible.

# %%
# !wget --quiet https://raw.githubusercontent.com/jurgjn/pooled-ppi/refs/heads/main/examples/sample-pools-mgen/sequences.tsv
# !echo "sequences.tsv has input sequence identifiers and lengths separated by whitespace:"
# !head -n 20 sequences.tsv
# Out:
# sequences.tsv has input sequence identifiers and lengths separated by whitespace:
# aac71217.2	380
# aac71218.2	310
# aac71219.1	650
# aac71220.1	836
# aac71221.1	417
# aac71222.1	210
# aac71223.1	254
# aac71224.1	442
# aac71225.1	262
# aac71226.1	218
# aac71227.1	287
# aac71228.1	287
# aac71229.2	273
# aac71230.1	623
# aac71231.1	589
# aac71234.2	1031
# aac71235.1	389
# aac71236.1	308
# aac71237.1	512
# aac71238.1	145

# %%
# !echo "Sample all-vs-all pools between first 20 input sequences"
# !head -n 20 sequences.tsv | pooled-ppi-sample --max_pool_size=5000
# Out:
# Sample all-vs-all pools between first 20 input sequences
# --init_pools None
# --max_pool_size 5000
# --max_pools None
# 2 threads available for numba
# 20 proteins in input
# 100% 190/190 [00:15<00:00, 12.52it/s]
# 5 pools generated
# 190 interactions expected
# 190 interactions across all pools generated
# True pools include all possible interactions
# 1.510508704306149 length-weighted redundancy factor across all pools
# pool_id	pool_size
# aac71217.2_aac71218.2_aac71219.1_aac71220.1_aac71221.1_aac71222.1_aac71223.1_aac71224.1_aac71225.1_aac71226.1_aac71227.1_aac71231.1_aac71238.1	5000
# aac71217.2_aac71222.1_aac71223.1_aac71225.1_aac71226.1_aac71228.1_aac71229.2_aac71230.1_aac71234.2_aac71235.1_aac71236.1_aac71237.1_aac71238.1	4892
# aac71218.2_aac71221.1_aac71224.1_aac71227.1_aac71228.1_aac71229.2_aac71230.1_aac71231.1_aac71235.1_aac71236.1_aac71237.1	4437
# aac71218.2_aac71219.1_aac71220.1_aac71227.1_aac71228.1_aac71229.2_aac71234.2_aac71235.1_aac71236.1_aac71237.1	4883
# aac71219.1_aac71220.1_aac71221.1_aac71224.1_aac71230.1_aac71231.1_aac71234.2	4588

# %%
# !echo "Sample all-vs-all pools proteome-wide (<2 min):"
# !cat sequences.tsv | pooled-ppi-sample --max_pool_size=5000 > sample-pools-mgen.tsv
# Out:
# Sample all-vs-all pools proteome-wide (<2 min):
# --init_pools None
# --max_pool_size 5000
# --max_pools None
# 2 threads available for numba
# 476 proteins in input
# 100% 113050/113050 [01:09<00:00, 1627.64it/s]
# 1865 pools generated
# 113050 interactions expected
# 113050 interactions across all pools generated
# True pools include all possible interactions
# 1.3318286112317754 length-weighted redundancy factor across all pools

# %%
# !echo "Number of pools slightly lower than originally (2,027) as sequence lengths included in optimisation:"
# !wc -l sample-pools-mgen.tsv
# !echo "Output has pool identifier (members separated by underscores) and pool size:"
# !head -n 5 sample-pools-mgen.tsv
# Out:
# Number of pools slightly lower than originally (2,027) as sequence lengths included in optimisation:
# 1866 sample-pools-mgen.tsv
# Output has pool identifier (members separated by underscores) and pool size:
# pool_id	pool_size
# aac71217.2_aac71218.2_aac71219.1_aac71220.1_aac71221.1_aac71222.1_aac71223.1_aac71224.1_aac71225.1_aac71226.1_aac71227.1_aac71228.1_aac71257.1_aac71564.1	4981
# aac71217.2_aac71229.2_aac71230.1_aac71231.1_aac71234.2_aac71235.1_aac71236.1_aac71237.1_aac71238.1_aac71239.1_aac71272.1_aac72463.1	4981
# aac71217.2_aac71240.1_aac71241.1_aac71242.1_aac71243.1_aac71244.1_aac71245.1_aac71246.1_aac71247.1_aac71248.1_aac71249.1_aac71250.1_aac71638.1_abc59632.1	4973
# aac71217.2_aac71251.1_aac71252.1_aac71253.1_aac71254.1_aac71255.1_aac71256.1_aac71258.1_aac71259.1_aac71260.1_aac71265.2_aac71461.2	4993
